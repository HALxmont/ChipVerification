# %%
import control
import numpy as np
import control.matlab as cmat
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Pixels vs current

# %%
data = pd.read_excel("tesis_base.xlsx")
data.columns = ['x', 'Pixels', 'Charges[q]', 'Amplitude[mA]']

# %%
data
# Out:
#          x  Pixels    Charges[q]  Amplitude[mA]
# 0        0       1  4.000000e-13              4
# 1        1       2  8.000000e-13              8
# 2        2       3  1.200000e-12             12
# 3        3       4  1.600000e-12             16
# 4        4       5  2.000000e-12             20
# ...    ...     ...           ...            ...
# 2995  2995    2996  1.198400e-09          11984
# 2996  2996    2997  1.198800e-09          11988
# 2997  2997    2998  1.199200e-09          11992
# 2998  2998    2999  1.199600e-09          11996
# 2999  2999    3000  1.200000e-09          12000
#
# [3000 rows x 4 columns]

# %%
fig = px.line(data, x ='Pixels', y = 'Amplitude[mA]', 
              labels={
                     "Pixels": "Pixels",
                     "Amplitude[mA]": "Amplitude [mA]"
                 })

fig.layout.title.text = 'Amplitude vs Activated Pixels'
fig.update_layout(
    #showlegend=False,
    plot_bgcolor="#f5f5f5",
    #margin=dict(t=10,l=10,b=10,r=10)
    title_x=0.5,
    #title_font_family="Old Standard TT",
    #legend_font_family="Old Standard TT",
    font_family="Cambria",
    font_size = 25,
    title_font_size=40

)


fig.write_image("amplitude-vs-pixels.pdf",width=0.8*1500, height=0.3*1500, scale=1)
fig.show()

# %%
fig = px.line(data, x ='Pixels', y = 'Charges[q]', 
              labels={
                     "Pixels": "Pixels",
                     "Charges[q]": "Charge [q]"
                 },)

fig.layout.title.text = 'Charge[q] vs Activated Pixels'
fig.update_layout(
    #showlegend=False,
    plot_bgcolor="#f5f5f5",
    #margin=dict(t=10,l=10,b=10,r=10)
    title_x=0.5,
    #title_font_family="Old Standard TT",
    #legend_font_family="Old Standard TT",
    font_family="Cambria",
    font_size = 25,
    title_font_size=40

    
)

fig.write_image("charge-vs-pixels.pdf",width=0.8*1500, height=0.3*1500, scale=1)
fig.show()
